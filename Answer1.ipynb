# %%
#upload .csv file from local machine
import pandas as pd
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-ded6c458-6cf3-4d54-ae7d-6eb0be1a7a89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ded6c458-6cf3-4d54-ae7d-6eb0be1a7a89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving main.csv to main (2).csv

# %%
url = '/content/main.csv'
cr = pd.read_csv("main.csv")

# %%
cr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
cr.Year = pd.to_datetime(cr.Year,format='%Y')
cr.Year
# Out:
# 0    1960-01-01
# 1    1961-01-01
# 2    1962-01-01
# 3    1963-01-01
# 4    1964-01-01
# 5    1965-01-01
# 6    1966-01-01
# 7    1967-01-01
# 8    1968-01-01
# 9    1969-01-01
# 10   1970-01-01
# 11   1971-01-01
# 12   1972-01-01
# 13   1973-01-01
# 14   1974-01-01
# 15   1975-01-01
# 16   1976-01-01
# 17   1977-01-01
# 18   1978-01-01
# 19   1979-01-01
# 20   1980-01-01
# 21   1981-01-01
# 22   1982-01-01
# 23   1983-01-01
# 24   1984-01-01
# 25   1985-01-01
# 26   1986-01-01
# 27   1987-01-01
# 28   1988-01-01
# 29   1989-01-01
# 30   1990-01-01
# 31   1991-01-01
# 32   1992-01-01
# 33   1993-01-01
# 34   1994-01-01
# 35   1995-01-01
# 36   1996-01-01
# 37   1997-01-01
# 38   1998-01-01
# 39   1999-01-01
# 40   2000-01-01
# 41   2001-01-01
# 42   2002-01-01
# 43   2003-01-01
# 44   2004-01-01
# 45   2005-01-01
# 46   2006-01-01
# 47   2007-01-01
# 48   2008-01-01
# 49   2009-01-01
# 50   2010-01-01
# 51   2011-01-01
# 52   2012-01-01
# 53   2013-01-01
# 54   2014-01-01
# ...

# %%
cr = cr.set_index('Year',drop=True)
cr
# Out:
#             Population     Total  ...  Larceny_Theft  Vehicle_Theft
# Year                              ...
# 1960-01-01   179323175   3384200  ...        1855400         328200
# 1961-01-01   182992000   3488000  ...        1913000         336000
# 1962-01-01   185771000   3752200  ...        2089600         366800
# 1963-01-01   188483000   4109500  ...        2297800         408300
# 1964-01-01   191141000   4564600  ...        2514400         472800
# 1965-01-01   193526000   4739400  ...        2572600         496900
# 1966-01-01   195576000   5223500  ...        2822000         561200
# 1967-01-01   197457000   5903400  ...        3111600         659800
# 1968-01-01   199399000   6720200  ...        3482700         783600
# 1969-01-01   201385000   7410900  ...        3888600         878500
# 1970-01-01   203235298   8098000  ...        4225800         928400
# 1971-01-01   206212000   8588200  ...        4424200         948200
# ...

# %%
del cr['Total']
cr.head()
# Out:
#             Population  Violent  ...  Larceny_Theft  Vehicle_Theft
# Year                             ...
# 1960-01-01   179323175   288460  ...        1855400         328200
# 1961-01-01   182992000   289390  ...        1913000         336000
# 1962-01-01   185771000   301510  ...        2089600         366800
# 1963-01-01   188483000   316970  ...        2297800         408300
# 1964-01-01   191141000   364220  ...        2514400         472800
#
# [5 rows x 10 columns]

# %%
crms = cr.resample('10AS').sum()

population = crms['Population'].resample('10AS').max()
print(population)
crms['Population'] = population
crms
# Out:
# Year
# 1960-01-01    1915053175
# 1970-01-01    2121193298
# 1980-01-01    2371370069
# 1990-01-01    2612825258
# 2000-01-01    2947969117
# 2010-01-01    1570146307
# Freq: 10AS-JAN, Name: Population, dtype: int64
#             Population      Total  ...  Larceny_Theft  Vehicle_Theft
# Year                               ...
# 1960-01-01  1915053175   49295900  ...       26547700        5292100
# 1970-01-01  2121193298  100991600  ...       53157800        9739900
# 1980-01-01  2371370069  131123369  ...       72040253       11935411
# 1990-01-01  2612825258  136582146  ...       77679366       14624418
# 2000-01-01  2947969117  115012044  ...       67970291       11412834
# 2010-01-01  1570146307   50167967  ...       30401698        3569080
#
# [6 rows x 11 columns]

# %%
crms.idxmax()
# Out:
# Population           2000-01-01
# Total                1990-01-01
# Violent              1990-01-01
# Property             1990-01-01
# Murder               1990-01-01
# Forcible_Rape        1990-01-01
# Robbery              1990-01-01
# Aggravated_assault   1990-01-01
# Burglary             1980-01-01
# Larceny_Theft        1990-01-01
# Vehicle_Theft        1990-01-01
# dtype: datetime64[ns]

# %%
from google.colab import files
crms.to_csv('output.csv')
files.download('output.csv')
